# %%
from google.colab import drive

#Conect your gmail drive to the netbook
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import os

# %%
def OpenFimg(p):
  with open(p) as f:
    numpy_data = np.fromfile(f, np.dtype("float32"))
    img = numpy_data[2:1392642]
    image = np.reshape(img, newshape=(1024, 1360))
    return image

# %%
list0 = os.listdir('/content/drive/MyDrive/Open_FIMGs/fimg_files')

# %%
print(list0)
# Out:
# ['FcParamImage_2023-10-14_16-53-27.fimg', 'FcParamImage_2023-10-14_16-53-27_2.fimg', 'FcParamImage_2023-10-14_16-53-27_1.fimg']

# %%
DIR = '/content/drive/MyDrive/Open_FIMGs/fimg_files/FcParamImage_2023-10-14_16-53-27_2.fimg'

# %%
with open(DIR) as f:
  numpy_data = np.fromfile(f, np.dtype("float32"))

# %%
print(numpy_data, np.max(numpy_data), np.min(numpy_data))
# Out:
# [ 1.9057659e-42  1.4349296e-42 -8.1616920e-01 ...  1.0422575e-01
#  -1.2654028e+00  4.9978185e-01] 0.7624442 -2041.3552
